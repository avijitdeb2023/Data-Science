# %% [markdown]
# <a href="https://colab.research.google.com/github/avijitdeb2023/Data-Science/blob/Coursera-Lab-Works/Coursera_ML(Lab_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2025-12-27 190316.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")

# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is: {m}")

#(OR we can write) m is the number of training examples
m = len(x_train)
print(f"Number of training examples is: {m}")

for i in range(m):
    x_i = x_train[i]
    y_i = y_train[i]
    print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")


w = float(input("Enter the value of w (weight): "))
b = float(input("Enter the value of b (bias): "))

print(f"\nYou entered:")
print(f"w: {w}")
print(f"b: {b}")


def compute_model_output(x, w, b):
  m = x_train.shape[0]
  f_wb = np.zeros(m)
  for i in range(m):
        f_wb[i] = w * x[i] + b

  return f_wb

tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]
# x_train.shape: (2,)
# Number of training examples is: 2
# Number of training examples is: 2
# (x^(0), y^(0)) = (1.0, 300.0)
# (x^(1), y^(1)) = (2.0, 500.0)
# Enter the value of w (weight): 250
# Enter the value of b (bias): 50
#
# You entered:
# w: 250.0
# b: 50.0
