# %% [markdown]
# <a href="https://colab.research.google.com/github/avijitdeb2023/Data-Science/blob/main/Assignment%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("========================================")
print("    Welcome to Skill Morph")
print("      Data Science Programme")
print("========================================")

name = input("Please enter your name: ")

print(f"\nHello, {name}!")
print("Let's begin our journey into Data Science with Python!")
print("Get ready to learn, explore, and create amazing things")
# Out:
# ...
#     Welcome to Skill Morph
#       Data Science Programme
# ...
# Please enter your name: Avijit
#
# Hello, Avijit!
# Let's begin our journey into Data Science with Python!
# Get ready to learn, explore, and create amazing things
